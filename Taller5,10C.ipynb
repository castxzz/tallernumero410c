# %%
nombre1 = "Manuela Salgado"
print(f"el primer integrante del grupo es {nombre1}")
# Out:
# el primer integrante del grupo es Manuela Salgado

# %%
nombre2 = "Samuel Castellanos"
print(f"el segundo integrante del grupo es {nombre2}")
# Out:
# el segundo integrante del grupo es Samuel Castellanos

# %%
curso = 10
print(f"nuestro curso es {curso}C")
# Out:
# nuestro curso es 10C

# %%
suma = 10+5
resta = 3-11
multiplicacion = 7*8
division = 9/4
print(suma)
print(resta)
print(multiplicacion)
print(division)
# Out:
# 15
# -8
# 56
# 2.25
